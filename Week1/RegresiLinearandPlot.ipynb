# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanFP26/MachineLearning/blob/main/Week1/RegresiLinearandPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Membuat Kumpulan Data
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 3 * X.squeeze() + 2 + np.random.randn(100) * 0.5

# %%
# Melakukan regresi linier
model = LinearRegression()
model.fit(X, y)

# Mencetak koefisien dan intersep
print('Coefficient: ', model.coef_)
print('Intercept: ', model.intercept_)

# Membuat prediksi menggunakan model
X_fit = np.linspace(0, 10, 100)[:, np.newaxis]
y_fit = model.predict(X_fit)
# Out:
# Coefficient:  [2.99684675]
# Intercept:  2.1110755387236093

# %%
# Memplot data asli dan garis regresi
plt.figure(figsize=(12,6))
plt.scatter(X.squeeze(), y)
plt.plot(X_fit.squeeze(), y_fit);
plt.title('Linear Regression Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
